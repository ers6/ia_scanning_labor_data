# %% [markdown]
# # Manifest Builder
# In this notebook we're cross walking our current data structures to the [manifest](https://github.com/hock/Manifest/wiki) supply chain data format.
#
# Plan to manually combine scanning centers with more than 1 scanning center id prior to brining into this notebook for real.
#
# ## Manifest Fields
#
# The Manifest [google sheets template](https://docs.google.com/spreadsheets/d/17P3kAShGgpSUV0P8f38zAlWYvF_Vxf8OldY6yriTfns/edit?usp=sharing ) has the following fields:
# - index: integer
# - Name: the name of the node (in our case the scanning center name)
# - description: a markdown description of the location. Can include links and such.
# - Category: types of locations. there can be more than one category per item. Given as # and separated by a comma, i.e., "#scanningcenter,#academiclibrary"
# - Images: a url leading to an image. If we wanted to include images of the scanning centers, we could do so using this.
# - Location: text description of the location, i.e., Allen County, IN
# - Geocode: the latitude and longitudinal coordinates of the location separated by a comma, i.e., "40.72401342,-74.0064435"
# - DestinationIndex: the index of any locations that the location should be connected to. For example, the destination index for the physical archive would include Datum Data, IA Hong Kong, and Innodata
# - Measure: any measure associated with the value including starttime and endtime. All measures consist of 3 values nested in parantheses (measure_name,measure_value,measure_unit). Measures are separated from each other by comma. For example, "(books_scanned,3800,books),(pages_scanned,252988,pages),(median_turnover,1127.0,days),(days_operated,2267.0,days),(starttime,1445467744,utc)"
#   - starttime: when the location becomes relevant to the supply chain given in UTC time, i.e., (starttime,1445467744,utc)
#   - endtime: when the location stops being relevant to the supply chain given in UTC time, i.e., (endtime,1445467744,utc)
# - Sources: any sources affiliated with the supply chain. In our case, we may include the actual links to texts scanned at that location in IA.
# - AdditionalNotes: I don't think these appear on manifest. it would be a good place to include all the values in the "scanningcenter" field that map to that scanning center. For example, UIUC could have this entry in AdditionalNotes: "scanningcenter values affiliated with this center include: "il" and "ill"

# %%
import pandas as pd

# %%
location_key = pd.read_csv("https://raw.githubusercontent.com/ers6/ia_scanning_labor_data/refs/heads/main/metadata-analysis/metadata-records-analysis-csvs/location_key.csv")
location_key
# Out:
#               scan_center        lat        long  \
# 0    1dollarscan (zLibro)  37.278389 -121.949260
# 1                 indiana  41.077129  -85.143200
# 2                 tt_amnh  40.781304  -73.974049
# 3           tt_numismatic  38.649678  -90.328482
# 4           tt_louisville  38.257598  -85.714221
# ..                    ...        ...         ...
# 103           tt_victoria  48.463375 -123.310025
# 104            tt_warwick  52.381617   -1.561842
# 105            tt_stlouis  38.649678  -90.328482
# 106               amherst  42.321888  -72.527668
# 107              hangzhou  30.262834  120.119013
#
#                                               name
# 0                                    1 Dollar Scan
# 1    Allen County Public Library Geneaology Center
# 2               American Museum of Natural History
# 3               Washington University in St. Louis
# 4            American Printing House for the Blind
# ..                                             ...
# 103                         University of Victoria
# 104                          University of Warwick
# 105             Washington University in St. Louis
# 106                            Yiddish Book Center
# 107                            Zhejiang University
#
# [108 rows x 4 columns]

# %%
location_key['long']
# Out:
# 0     -121.949260
# 1      -85.143200
# 2      -73.974049
# 3      -90.328482
# 4      -85.714221
#           ...
# 103   -123.310025
# 104     -1.561842
# 105    -90.328482
# 106    -72.527668
# 107    120.119013
# Name: long, Length: 108, dtype: float64

# %%
center_names = []
centers = []

for i in range(len(location_key)):
    if location_key.at[i, 'name'] in center_names:
        this_id = location_key.at[i, 'scan_center']
        for this_center in centers: 
            if this_center['name'] == location_key.at[i, 'name']: 
                this_center['scanningcenter_ids'] += str( "||" + this_id)
            else:pass
        # need to append the scanning center id here somehow ... i think this needs to be a dataframe ugh 
    else: 
        centers.append({
            'name': location_key.at[i, 'name'],
            'lat': str(location_key.at[i, 'lat']),
            'long': str(location_key.at[i, 'long']),
            'scanningcenter_ids': str(location_key.at[i, 'scan_center']) 
        })
        center_names.append(location_key.at[i, 'name'])

# %%
centers_df = pd.DataFrame(centers)
centers_df
# Out:
#                                              name          lat          long  \
# 0                                   1 Dollar Scan  37.27838889  -121.9492601
# 1   Allen County Public Library Geneaology Center   41.0771285   -85.1432003
# 2              American Museum of Natural History  40.78130431  -73.97404878
# 3              Washington University in St. Louis    38.649678  -90.32848246
# 4           American Printing House for the Blind  38.25759766  -85.71422071
# ..                                            ...          ...           ...
# 71                          University of Toronto  43.66441368  -79.39947221
# 72                         University of Victoria   48.4633746  -123.3100252
# 73                          University of Warwick  52.38161719  -1.561841996
# 74                            Yiddish Book Center  42.32188825  -72.52766762
# 75                            Zhejiang University   30.2628344   120.1190128
#
#            scanningcenter_ids
# 0        1dollarscan (zLibro)
# 1                     indiana
# 2                     tt_amnh
# 3   tt_numismatic||tt_stlouis
# 4               tt_louisville
# ..                        ...
# 71                 uoft||UofT
# 72                tt_victoria
# 73                 tt_warwick
# 74                    amherst
# 75                   hangzhou
#
# [76 rows x 4 columns]

# %%
def make_geocords(lat, long): 
    return str(lat) + ',' + str(long)

# https://archive.org/search?query=scanningcenter%3A%28cebu%29
def get_ia_links(center_ids): 
    links = []
    for this_id in center_ids.split('||'): 
        links.append("https://archive.org/search?query=scanningcenter%3A%28" + str(this_id.replace(" ", "")) + "%29"
        )
    formatted_links = ""
    if len(links) > 1:
        for i in range(len(links)): 
            if i < (len(links)):
                formatted_links += "(" + links[i] + "),"
            else: 
                formatted_links += "(" + links[i] + ")"
    else: 
        formatted_links =  "(" + links[0] + ")"
    return formatted_links

# %%
get_ia_links(centers_df.at[5, 'scanningcenter_ids'])
# Out:
# '(https://archive.org/search?query=scanningcenter%3A%28tt_swinburne%29)'

# %%
manifest_data = []
for i in range(len(centers_df)): 
    manifest_data.append(
        {'Index': i,
         'Name': centers_df.at[i, 'name'], 
         'Description': '',
         'Category': '',
         'Images': '',
         'Location':'',
         'Geocode': make_geocords(centers_df.at[i, 'lat'], centers_df.at[i, 'long']),
         'DestinationIndex': '',
         'Measure':'',
         'Sources': get_ia_links(centers_df.at[i, 'scanningcenter_ids']),
         'AdditionalNotes':'Scanning center ids separated by "||": ' + str(centers_df.at[i,'scanningcenter_ids'])
        }
    )

# %%
manifest_data
# Out:
# [{'Index': 0,
#   'Name': '1 Dollar Scan',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.27838889,-121.9492601',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%281dollarscan(zLibro)%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": 1dollarscan (zLibro)'},
#  {'Index': 1,
#   'Name': 'Allen County Public Library Geneaology Center',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '41.0771285,-85.1432003',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28indiana%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": indiana'},
#  {'Index': 2,
#   'Name': 'American Museum of Natural History',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.78130431,-73.97404878',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_amnh%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_amnh'},
#  {'Index': 3,
#   'Name': 'Washington University in St. Louis',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.649678,-90.32848246',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_numismatic%29),(https://archive.org/search?query=scanningcenter%3A%28tt_stlouis%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_numismatic||tt_stlouis'},
#  {'Index': 4,
#   'Name': 'American Printing House for the Blind',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.25759766,-85.71422071',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_louisville%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_louisville'},
#  {'Index': 5,
#   'Name': 'Analysis and Policy Observatory (APO)',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '-37.82242623,145.0393157',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_swinburne%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_swinburne'},
#  {'Index': 6,
#   'Name': 'BookScanUS',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '32.23962014,-110.9556127',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28BookScanUS%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": BookScanUS'},
#  {'Index': 7,
#   'Name': 'Boston Public Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '42.34936189,-71.07819992',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28boston%29),(https://archive.org/search?query=scanningcenter%3A%28Boston%29),(https://archive.org/search?query=scanningcenter%3A%28tt_bostonuniversity%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": boston||Boston||tt_bostonuniversity'},
#  {'Index': 8,
#   'Name': 'British Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '51.53000987,-0.1275571138',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28euston%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": euston'},
#  {'Index': 9,
#   'Name': 'Brown University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '41.82567677,-71.40513051',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28providence%29),(https://archive.org/search?query=scanningcenter%3A%28tt_providence%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": providence||tt_providence'},
#  {'Index': 10,
#   'Name': 'BYU, Hawaii',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '21.64181757,-157.9265819',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28honolulu%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": honolulu'},
#  {'Index': 11,
#   'Name': 'BYU, Idaho Family History Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '43.81949648,-111.7827966',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28rexburg%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": rexburg'},
#  {'Index': 12,
#   'Name': 'BYU, Provo',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.24883196,-111.6492385',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28provo%29),(https://archive.org/search?query=scanningcenter%3A%28brussels%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": provo||brussels'},
#  {'Index': 13,
#   'Name': 'California Academy of Sciences',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.76985038,-121.4962605',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_calacademy%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_calacademy'},
#  {'Index': 14,
#   'Name': 'California State Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.57589327,-121.4962643',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28sacramento%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": sacramento'},
#  {'Index': 15,
#   'Name': 'Centre for Strategic and International Studies, Jakarta',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '-6.177154589,106.8164464',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_jakarta%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_jakarta'},
#  {'Index': 16,
#   'Name': 'Church History Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.77200728,-111.8906814',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28saltlakecity%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": saltlakecity'},
#  {'Index': 17,
#   'Name': 'Clatsop County Historical Society',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '46.1884006,-123.8253618',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_clatsopcounty%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_clatsopcounty'},
#  {'Index': 18,
#   'Name': 'Clemson University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '34.67661443,-82.8364096',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28clemson%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": clemson'},
#  {'Index': 19,
#   'Name': 'Columbia University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.80657713,-73.96320572',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28nyc%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": nyc'},
#  {'Index': 20,
#   'Name': 'Datum Data Co. Ltd.',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '22.50635114,114.0501618',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28shenzhen%29),(https://archive.org/search?query=scanningcenter%3A%28china%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": shenzhen||china'},
#  {'Index': 21,
#   'Name': 'Duke University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '36.00294192,-78.93834083',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28durham%29),(https://archive.org/search?query=scanningcenter%3A%28durham2%29),(https://archive.org/search?query=scanningcenter%3A%28Durham%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": durham||durham2||Durham'},
#  {'Index': 22,
#   'Name': 'Family Search Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.77037084,-111.8945972',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28utah%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": utah'},
#  {'Index': 23,
#   'Name': 'Georgetown University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.90659981,-77.07223903',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_georgetown%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_georgetown'},
#  {'Index': 24,
#   'Name': 'Getty Research Institute',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '34.0769306,-118.4754969',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_getty%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_getty'},
#  {'Index': 25,
#   'Name': 'Getty Research Institute Valencia Warehouse',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '34.0769306,-118.4754969',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28valencia%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": valencia'},
#  {'Index': 26,
#   'Name': 'Hamilton Public Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '43.25893488,-79.87052526',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28hamilton%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": hamilton'},
#  {'Index': 27,
#   'Name': 'Harvard',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '42.37357506,-71.11649816',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_harvardernstmayr%29),(https://archive.org/search?query=scanningcenter%3A%28tt_harvardwidener%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_harvardernstmayr||tt_harvardwidener'},
#  {'Index': 28,
#   'Name': 'Internet Archive China',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '22.39964476,114.1931671',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28hongkong%29),(https://archive.org/search?query=scanningcenter%3A%28HongKong%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": hongkong||Hong Kong'},
#  {'Index': 29,
#   'Name': 'Hopewell Junction',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '41.58494026,-73.8016634',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28poughkeepsie%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": poughkeepsie'},
#  {'Index': 30,
#   'Name': 'Innodata Knowledge Services, Inc.',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '10.31810777,123.9197947',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28cebu%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": cebu'},
#  {'Index': 31,
#   'Name': 'International Institute of Information Technology Hyderabad',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '17.44586255,78.34932817',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28IIITHyderabad%29),(https://archive.org/search?query=scanningcenter%3A%28CCLHYDERBAD%29),(https://archive.org/search?query=scanningcenter%3A%28CCLHYDERABAD%29),(https://archive.org/search?query=scanningcenter%3A%28S.V.DigitalLibraryTTD%29),(https://archive.org/search?query=scanningcenter%3A%28CCLHYDERABAD%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": IIIT Hyderabad||CCLHYDERBAD||CCLHYDERABAD||S.V.Digital LibraryTTD||CCL HYDERABAD'},
#  {'Index': 32,
#   'Name': 'Internet Archive Headquarters',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.78244229,-122.4717902',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28sfdowntown%29),(https://archive.org/search?query=scanningcenter%3A%28sanfrancisco%29),(https://archive.org/search?query=scanningcenter%3A%28arch%29),(https://archive.org/search?query=scanningcenter%3A%28tt_sanfrancisco%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": sfdowntown||sanfrancisco||arch||tt_sanfrancisco'},
#  {'Index': 33,
#   'Name': 'Internet Archive Sheridan Headquarters',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '39.3290796,-122.4603688',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28sheridan%29),(https://archive.org/search?query=scanningcenter%3A%28miss%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": sheridan||miss'},
#  {'Index': 34,
#   'Name': 'Internt Archive Physical Archive',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.92940204,-122.3459016',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28rich%29),(https://archive.org/search?query=scanningcenter%3A%28richmond%29),(https://archive.org/search?query=scanningcenter%3A%28richflorida%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": rich||richmond||richflorida'},
#  {'Index': 35,
#   'Name': 'John Hopkins University Library Offsite Storage',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '39.20608234,-76.94551344',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28clarksville%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": clarksville'},
#  {'Index': 36,
#   'Name': 'Kahle/Austin Foundation',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.79555743,-122.4493788',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28Kahle/AustinFoundation%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": Kahle/Austin Foundation'},
#  {'Index': 37,
#   'Name': 'Library of Congress',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.88870235,-77.00481291',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28capitolhill%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": capitolhill'},
#  {'Index': 38,
#   'Name': 'Missouri Botanical Garden',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.61688951,-90.26274302',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28mobot%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": mobot'},
#  {'Index': 39,
#   'Name': 'National Agricultural Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '39.022774,-76.9217401',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28beltsville%29),(https://archive.org/search?query=scanningcenter%3A%28edinburgh%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": beltsville||edinburgh'},
#  {'Index': 40,
#   'Name': 'Natural History Museum Library, London',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '51.49684189,-0.176270642',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28london%29),(https://archive.org/search?query=scanningcenter%3A%28lond%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": london||lond'},
#  {'Index': 41,
#   'Name': 'New York Botanical Garden',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.86660468,-73.87875668',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_nybg%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_nybg'},
#  {'Index': 42,
#   'Name': 'North Carolina State University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '35.78748428,-78.66939426',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28raleigh%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": raleigh'},
#  {'Index': 43,
#   'Name': 'Oberlin College Libraries',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '41.29341848,-82.22281366',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_oberlin%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_oberlin'},
#  {'Index': 44,
#   'Name': 'Osmania University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '17.41717781,78.52560833',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28OsmaniaUniversity%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": Osmania University'},
#  {'Index': 45,
#   'Name': 'Peabody Essex Museum',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '42.52157514,-70.89222149',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_pem%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_pem'},
#  {'Index': 46,
#   'Name': 'Perkins School for the Blind',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '42.3616051,-71.17784952',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_perkins%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_perkins'},
#  {'Index': 47,
#   'Name': 'Perpustakaan Provinsi Bali',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '-8.685606156,115.2297763',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28bali%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": bali'},
#  {'Index': 48,
#   'Name': 'Press Academy of Andhra Pradesh',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '17.39517291,78.47138682',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28APPressAcademyArchives%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": AP Press Academy Archives'},
#  {'Index': 49,
#   'Name': 'Princeton University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.34956609,-74.65738623',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28nj%29),(https://archive.org/search?query=scanningcenter%3A%28tt_pts%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": nj||tt_pts'},
#  {'Index': 50,
#   'Name': 'Regional Mega Scanning Center by IIT, Hyderbad',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '17.4462589,78.3484708',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28RMSC-IIITH%29),(https://archive.org/search?query=scanningcenter%3A%28RMSC_IIITH%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": RMSC-IIITH||RMSC_IIITH'},
#  {'Index': 51,
#   'Name': 'Research Institute of Korean Studies',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.5928363,127.0264268',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_riks%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_riks'},
#  {'Index': 52,
#   'Name': 'San Francisco Public Library',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.77914204,-122.4157906',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28sfciviccenter%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": sfciviccenter'},
#  {'Index': 53,
#   'Name': 'The Servants of Knowledge',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '12.966384,77.6352956',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_bangalore%29),(https://archive.org/search?query=scanningcenter%3A%28tt_sok%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_bangalore||tt_sok'},
#  {'Index': 54,
#   'Name': 'Smithsonian Libraries and Archives',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.89132735,-77.02586404',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28washingtondc%29),(https://archive.org/search?query=scanningcenter%3A%28Capitolhill%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": washingtondc||Capitolhill'},
#  {'Index': 55,
#   'Name': 'Stanford University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '37.4239279,-122.1674727',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_stanfordlaw%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_stanfordlaw'},
#  {'Index': 56,
#   'Name': 'State Library of Pennsylvania',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.2650287,-76.88065236',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28harrisburg%29),(https://archive.org/search?query=scanningcenter%3A%28tt_harrisburg%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": harrisburg||tt_harrisburg'},
#  {'Index': 57,
#   'Name': 'Staten Island Museum',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.64455096,-74.10269554',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_statenisland%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_statenisland'},
#  {'Index': 58,
#   'Name': 'The Archive of Contemporary Music',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.71867548,-74.00374316',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28manhattan%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": manhattan'},
#  {'Index': 59,
#   'Name': 'The Ohio State University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '39.99926893,-83.01493372',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_osu%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_osu'},
#  {'Index': 60,
#   'Name': 'Trent University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '44.35722473,-78.29034148',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28trent%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": trent'},
#  {'Index': 61,
#   'Name': 'UCLA',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '34.07168305,-118.442185',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28la%29),(https://archive.org/search?query=scanningcenter%3A%28iala%29),(https://archive.org/search?query=scanningcenter%3A%28santamonica%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": la||iala||santamonica'},
#  {'Index': 62,
#   'Name': 'UIUC',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.10440926,-88.22933583',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28ill%29),(https://archive.org/search?query=scanningcenter%3A%28il%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": ill||il'},
#  {'Index': 63,
#   'Name': 'UNC Chapel Hill',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '35.91097779,-79.0487334',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28chapelhill%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": chapelhill'},
#  {'Index': 64,
#   'Name': 'Universidad Francisco Marroquín',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '14.6054948,-90.50534962',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28guatemala%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": guatemala'},
#  {'Index': 65,
#   'Name': 'University of Alberta',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '53.5264397,-113.5254331',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28alberta%29),(https://archive.org/search?query=scanningcenter%3A%28alberta%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": alberta||alberta'},
#  {'Index': 66,
#   'Name': 'University of Chinese Academy of Sciences',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '40.40814427,116.6823424',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28beijing%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": beijing'},
#  {'Index': 67,
#   'Name': 'University of Connecticut',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '41.80696142,-72.25146626',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28hbl_storrs%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": hbl_storrs'},
#  {'Index': 68,
#   'Name': 'University of Florida',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '29.6516662,-82.3445709',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28gainesville%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": gainesville'},
#  {'Index': 69,
#   'Name': 'University of Maryland, College Park',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '38.9860937,-76.9456868',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28maryland%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": maryland'},
#  {'Index': 70,
#   'Name': 'University of Pretoria',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '-25.7553205,28.2295439',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28pretoria%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": pretoria'},
#  {'Index': 71,
#   'Name': 'University of Toronto',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '43.66441368,-79.39947221',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28uoft%29),(https://archive.org/search?query=scanningcenter%3A%28UofT%29),',
#   'AdditionalNotes': 'Scanning center ids separated by "||": uoft||UofT'},
#  {'Index': 72,
#   'Name': 'University of Victoria',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '48.4633746,-123.3100252',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_victoria%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_victoria'},
#  {'Index': 73,
#   'Name': 'University of Warwick',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '52.38161719,-1.561841996',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28tt_warwick%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": tt_warwick'},
#  {'Index': 74,
#   'Name': 'Yiddish Book Center',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '42.32188825,-72.52766762',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28amherst%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": amherst'},
#  {'Index': 75,
#   'Name': 'Zhejiang University',
#   'Description': '',
#   'Category': '',
#   'Images': '',
#   'Location': '',
#   'Geocode': '30.2628344,120.1190128',
#   'DestinationIndex': '',
#   'Measure': '',
#   'Sources': '(https://archive.org/search?query=scanningcenter%3A%28hangzhou%29)',
#   'AdditionalNotes': 'Scanning center ids separated by "||": hangzhou'}]

# %%
for i in range(len(manifest_data)):
    # subsetting the location dataframe for only entries with the same entry in the same field (same center)
    locs = location_key[location_key["name"] == manifest_data[i]['Name']].reset_index()
    print(locs)
    try:
        # assuming that every center that shares the same name is the same center and should have the same geographic coordinates 
        manifest_data[i]['Geocode'] = str(locs.at[0, 'lat']) + ',' +  str(locs.at[0, 'long'])
        # print(manifest_data[i]['Geocode'])
    except KeyError:
        pass
    except ValueError:
        pass
# Out:
#    index           scan_center        lat       long           name
# 0      0  1dollarscan (zLibro)  37.278389 -121.94926  1 Dollar Scan
#    index scan_center        lat     long  \
# 0      1     indiana  41.077129 -85.1432
#
#                                             name
# 0  Allen County Public Library Geneaology Center
#    index scan_center        lat       long                                name
# 0      2     tt_amnh  40.781304 -73.974049  American Museum of Natural History
#    index    scan_center        lat       long  \
# 0      3  tt_numismatic  38.649678 -90.328482
# 1    105     tt_stlouis  38.649678 -90.328482
#
#                                  name
# 0  Washington University in St. Louis
# 1  Washington University in St. Louis
#    index    scan_center        lat       long  \
# 0      4  tt_louisville  38.257598 -85.714221
#
#                                     name
# 0  American Printing House for the Blind
#    index   scan_center        lat        long  \
# 0      5  tt_swinburne -37.822426  145.039316
#
#                                     name
# 0  Analysis and Policy Observatory (APO)
#    index scan_center       lat        long        name
# 0      6  BookScanUS  32.23962 -110.955613  BookScanUS
#    index          scan_center        lat     long                   name
# 0      7               boston  42.349362 -71.0782  Boston Public Library
# 1      8               Boston  42.349362 -71.0782  Boston Public Library
# 2      9  tt_bostonuniversity  42.349362 -71.0782  Boston Public Library
#    index scan_center       lat      long             name
# 0     10      euston  51.53001 -0.127557  British Library
#    index    scan_center        lat       long              name
# 0     11     providence  41.825677 -71.405131  Brown University
# 1     12  tt_providence  41.825677 -71.405131  Brown University
#    index scan_center        lat        long         name
# 0     13    honolulu  21.641818 -157.926582  BYU, Hawaii
#    index scan_center        lat        long                               name
# 0     14     rexburg  43.819496 -111.782797  BYU, Idaho Family History Library
#    index scan_center        lat        long        name
# 0     15       provo  40.248832 -111.649238  BYU, Provo
# 1     16    brussels  40.248832 -111.649238  BYU, Provo
#    index    scan_center       lat        long                            name
# 0     17  tt_calacademy  37.76985 -121.496261  California Academy of Sciences
#    index scan_center        lat        long                      name
# 0     18  sacramento  38.575893 -121.496264  California State Library
#    index scan_center       lat        long  \
# 0     19  tt_jakarta -6.177155  106.816446
#
#                                                 name
# 0  Centre for Strategic and International Studies...
#    index   scan_center        lat        long                    name
# 0     20  saltlakecity  40.772007 -111.890681  Church History Library
#    index       scan_center        lat        long  \
# 0     21  tt_clatsopcounty  46.188401 -123.825362
#
#                                 name
# 0  Clatsop County Historical Society
#    index scan_center        lat      long                name
# 0     22     clemson  34.676614 -82.83641  Clemson University
#    index scan_center        lat       long                 name
# 0     23         nyc  40.806577 -73.963206  Columbia University
#    index scan_center        lat        long                 name
# 0     24    shenzhen  22.506351  114.050162  Datum Data Co. Ltd.
# 1     25       china  22.506351  114.050162  Datum Data Co. Ltd.
#    index scan_center        lat       long             name
# 0     26      durham  36.002942 -78.938341  Duke University
# 1     27     durham2  36.002942 -78.938341  Duke University
# 2     28      Durham  36.002942 -78.938341  Duke University
#    index scan_center        lat        long                   name
# 0     29        utah  40.770371 -111.894597  Family Search Library
#    index    scan_center      lat       long                   name
# 0     30  tt_georgetown  38.9066 -77.072239  Georgetown University
#    index scan_center        lat        long                      name
# 0     31    tt_getty  34.076931 -118.475497  Getty Research Institute
#    index scan_center        lat        long  \
# 0     32    valencia  34.076931 -118.475497
#
#                                           name
# 0  Getty Research Institute Valencia Warehouse
#    index scan_center        lat       long                     name
# 0     33    hamilton  43.258935 -79.870525  Hamilton Public Library
#    index          scan_center        lat       long     name
# 0     34  tt_harvardernstmayr  42.373575 -71.116498  Harvard
# 1     35    tt_harvardwidener  42.373575 -71.116498  Harvard
#    index scan_center        lat        long                    name
# 0     36    hongkong  22.399645  114.193167  Internet Archive China
# 1     37   Hong Kong  22.399645  114.193167  Internet Archive China
#    index   scan_center       lat       long               name
# 0     38  poughkeepsie  41.58494 -73.801663  Hopewell Junction
#    index scan_center        lat        long                               name
# 0     39        cebu  10.318108  123.919795  Innodata Knowledge Services, Inc.
#    index             scan_center        lat       long  \
# 0     40          IIIT Hyderabad  17.445863  78.349328
# 1     41             CCLHYDERBAD  17.445863  78.349328
# 2     42            CCLHYDERABAD  17.445863  78.349328
# 3     43  S.V.Digital LibraryTTD  17.445863  78.349328
# 4     44           CCL HYDERABAD  17.445863  78.349328
#
#                                                 name
# 0  International Institute of Information Technol...
# 1  International Institute of Information Technol...
# 2  International Institute of Information Technol...
# 3  International Institute of Information Technol...
# 4  International Institute of Information Technol...
#    index      scan_center        lat        long  \
# 0     45       sfdowntown  37.782442 -122.471790
# 1     46     sanfrancisco  37.782442 -122.471790
# 2     47             arch  37.800396 -122.460364
# 3     48  tt_sanfrancisco  37.782442 -122.471790
#
#                             name
# 0  Internet Archive Headquarters
# 1  Internet Archive Headquarters
# 2  Internet Archive Headquarters
# 3  Internet Archive Headquarters
#    index scan_center        lat        long  \
# 0     49    sheridan  39.329080 -122.460369
# 1     50        miss  39.327293 -122.460369
#
#                                      name
# 0  Internet Archive Sheridan Headquarters
# 1  Internet Archive Sheridan Headquarters
#    index  scan_center        lat        long                              name
# 0     51         rich  37.929402 -122.345902  Internt Archive Physical Archive
# 1     52     richmond  37.929402 -122.345902  Internt Archive Physical Archive
# 2     53  richflorida  37.929402 -122.345902  Internt Archive Physical Archive
#    index  scan_center        lat       long  \
# 0     54  clarksville  39.206082 -76.945513
#
#                                               name
# 0  John Hopkins University Library Offsite Storage
#    index              scan_center        lat        long  \
# 0     55  Kahle/Austin Foundation  37.795557 -122.449379
#
#                       name
# 0  Kahle/Austin Foundation
#    index  scan_center        lat       long                 name
# 0     56  capitolhill  38.888702 -77.004813  Library of Congress
#    index scan_center       lat       long                       name
# 0     57       mobot  38.61689 -90.262743  Missouri Botanical Garden
#    index scan_center        lat       long                           name
# 0     58  beltsville  39.022774 -76.921740  National Agricultural Library
# 1     59   edinburgh  55.948704  -3.191972  National Agricultural Library
#    index scan_center        lat      long  \
# 0     60      london  51.496842 -0.176271
# 1     61        lond  51.496842 -0.176271
#
#                                      name
# 0  Natural History Museum Library, London
# 1  Natural History Museum Library, London
#    index scan_center        lat       long                       name
# 0     62     tt_nybg  40.866605 -73.878757  New York Botanical Garden
#    index scan_center        lat       long                             name
# 0     63     raleigh  35.787484 -78.669394  North Carolina State University
#    index scan_center        lat       long                       name
# 0     64  tt_oberlin  41.293418 -82.222814  Oberlin College Libraries
#    index         scan_center        lat       long                name
# 0     65  Osmania University  17.417178  78.525608  Osmania University
#    index scan_center        lat       long                  name
# 0     66      tt_pem  42.521575 -70.892221  Peabody Essex Museum
#    index scan_center        lat      long                          name
# 0     67  tt_perkins  42.361605 -71.17785  Perkins School for the Blind
#    index scan_center       lat        long                        name
# 0     68        bali -8.685606  115.229776  Perpustakaan Provinsi Bali
#    index                scan_center        lat       long  \
# 0     69  AP Press Academy Archives  17.395173  78.471387
#
#                               name
# 0  Press Academy of Andhra Pradesh
#    index scan_center        lat       long                  name
# 0     70          nj  40.349566 -74.657386  Princeton University
# 1     71      tt_pts  40.349566 -74.657386  Princeton University
#    index scan_center        lat       long  \
# 0     72  RMSC-IIITH  17.446259  78.348471
# 1     73  RMSC_IIITH  17.446259  78.348471
#
#                                              name
# 0  Regional Mega Scanning Center by IIT, Hyderbad
# 1  Regional Mega Scanning Center by IIT, Hyderbad
#    index scan_center        lat        long  \
# 0     74     tt_riks  37.592836  127.026427
#
#                                    name
# 0  Research Institute of Korean Studies
#    index    scan_center        lat        long                          name
# 0     75  sfciviccenter  37.779142 -122.415791  San Francisco Public Library
#    index   scan_center        lat       long                       name
# 0     76  tt_bangalore  12.966384  77.635296  The Servants of Knowledge
# 1     85        tt_sok  12.966384  77.635296  The Servants of Knowledge
#    index   scan_center        lat       long  \
# 0     77  washingtondc  38.891327 -77.025864
# 1     78   Capitolhill  38.891261 -77.025864
#
#                                  name
# 0  Smithsonian Libraries and Archives
# 1  Smithsonian Libraries and Archives
#    index     scan_center        lat        long                 name
# 0     79  tt_stanfordlaw  37.423928 -122.167473  Stanford University
#    index    scan_center        lat       long                           name
# 0     80     harrisburg  40.265029 -76.880652  State Library of Pennsylvania
# 1     81  tt_harrisburg  40.265029 -76.880652  State Library of Pennsylvania
#    index      scan_center        lat       long                  name
# 0     82  tt_statenisland  40.644551 -74.102696  Staten Island Museum
#    index scan_center        lat       long                               name
# 0     83   manhattan  40.718675 -74.003743  The Archive of Contemporary Music
#    index scan_center        lat       long                       name
# 0     84      tt_osu  39.999269 -83.014934  The Ohio State University
#    index scan_center        lat       long              name
# 0     86       trent  44.357225 -78.290341  Trent University
#    index  scan_center        lat        long  name
# 0     87           la  34.071683 -118.442185  UCLA
# 1     88         iala  34.071683 -118.442185  UCLA
# 2     89  santamonica  34.071683 -118.442185  UCLA
#    index scan_center        lat       long  name
# 0     90         ill  40.104409 -88.229336  UIUC
# 1     91          il  40.104409 -88.229336  UIUC
#    index scan_center        lat       long             name
# 0     92  chapelhill  35.910978 -79.048733  UNC Chapel Hill
#    index scan_center        lat      long                             name
# 0     93   guatemala  14.605495 -90.50535  Universidad Francisco Marroquín
#    index scan_center       lat        long                   name
# 0     94     alberta  53.52644 -113.525433  University of Alberta
# 1     95     alberta  53.52644 -113.525433  University of Alberta
#    index scan_center        lat        long  \
# 0     96     beijing  40.408144  116.682342
#
#                                         name
# 0  University of Chinese Academy of Sciences
#    index scan_center        lat       long                       name
# 0     97  hbl_storrs  41.806961 -72.251466  University of Connecticut
#    index  scan_center        lat       long                   name
# 0     98  gainesville  29.651666 -82.344571  University of Florida
#    index scan_center        lat       long  \
# 0     99    maryland  38.986094 -76.945687
#
#                                    name
# 0  University of Maryland, College Park
#    index scan_center       lat       long                    name
# 0    100    pretoria -25.75532  28.229544  University of Pretoria
#    index scan_center        lat       long                   name
# 0    101        uoft  43.664414 -79.399472  University of Toronto
# 1    102        UofT  43.664414 -79.399472  University of Toronto
#    index  scan_center        lat        long                    name
# 0    103  tt_victoria  48.463375 -123.310025  University of Victoria
#    index scan_center        lat      long                   name
# 0    104  tt_warwick  52.381617 -1.561842  University of Warwick
#    index scan_center        lat       long                 name
# 0    106     amherst  42.321888 -72.527668  Yiddish Book Center
#    index scan_center        lat        long                 name
# 0    107    hangzhou  30.262834  120.119013  Zhejiang University

# %%
len(manifest_data)
# Out:
# 76

# %%
manifest_df = pd.DataFrame.from_dict(manifest_data)

# %% [markdown]
# ## Category
#
# adding category info to the scanning centers

# %%
center_types = pd.read_csv("https://raw.githubusercontent.com/ers6/ia_scanning_labor_data/refs/heads/main/metadata-analysis/metadata-records-analysis-csvs/scan-center-type.csv")[['name', 'type']]

# %%
center_types = center_types.drop_duplicates().reset_index()[['name','type']]

# %%
center_types
# Out:
#                                  name        type
# 0   Innodata Knowledge Services, Inc.         bpo
# 1                           Hong Kong         bpo
# 2               University of Alberta    academic
# 3       Internet Archive Headquarters          hq
# 4                 Datum Data Co. Ltd.         bpo
# ..                                ...         ...
# 74    Press Academy of Andhra Pradesh     archive
# 75            Hamilton Public Library      public
# 76          New York Botanical Garden      museum
# 77          Missouri Botanical Garden      museum
# 78         Perpustakaan Provinsi Bali  government
#
# [79 rows x 2 columns]

# %%
for i in range(len(manifest_df)): 
    for j in range(len(center_types)): 
        if manifest_df.at[i, 'Name'] == center_types.at[j, 'name']: 
            manifest_df.at[i, 'Category'] = "#"+ str(center_types.at[j, 'type'])
        else: 
            pass 

for i in range(len(manifest_df)): 
    if manifest_df.at[i, 'Category'] == "#nan":
        manifest_df.at[i, 'Category'] = ''
    else:
        pass

# %%
manifest_df
# Out:
#     Index                                           Name Description  \
# 0       0                                  1 Dollar Scan
# 1       1  Allen County Public Library Geneaology Center
# 2       2             American Museum of Natural History
# 3       3             Washington University in St. Louis
# 4       4          American Printing House for the Blind
# ..    ...                                            ...         ...
# 71     71                          University of Toronto
# 72     72                         University of Victoria
# 73     73                          University of Warwick
# 74     74                            Yiddish Book Center
# 75     75                            Zhejiang University
#
#      Category Images Location                   Geocode DestinationIndex  \
# 0                              37.27838889,-121.9492601
# 1     #public                    41.0771285,-85.1432003
# 2     #museum                  40.78130431,-73.97404878
# 3   #academic                    38.649678,-90.32848246
# 4    #archive                  38.25759766,-85.71422071
# ..        ...    ...      ...                       ...              ...
# 71  #academic                  43.66441368,-79.39947221
# 72  #academic                   48.4633746,-123.3100252
# 73  #academic                  52.38161719,-1.561841996
# 74  #academic                  42.32188825,-72.52766762
# 75  #academic                    30.2628344,120.1190128
#
#    Measure                                            Sources  \
# 0           (https://archive.org/search?query=scanningcent...
# 1           (https://archive.org/search?query=scanningcent...
# 2           (https://archive.org/search?query=scanningcent...
# 3           (https://archive.org/search?query=scanningcent...
# 4           (https://archive.org/search?query=scanningcent...
# ..     ...                                                ...
# 71          (https://archive.org/search?query=scanningcent...
# 72          (https://archive.org/search?query=scanningcent...
# 73          (https://archive.org/search?query=scanningcent...
# 74          (https://archive.org/search?query=scanningcent...
# 75          (https://archive.org/search?query=scanningcent...
#
#                                       AdditionalNotes
# 0   Scanning center ids separated by "||": 1dollar...
# 1      Scanning center ids separated by "||": indiana
# 2      Scanning center ids separated by "||": tt_amnh
# 3   Scanning center ids separated by "||": tt_numi...
# 4   Scanning center ids separated by "||": tt_loui...
# ..                                                ...
# 71  Scanning center ids separated by "||": uoft||UofT
# 72  Scanning center ids separated by "||": tt_vict...
# 73  Scanning center ids separated by "||": tt_warwick
# 74     Scanning center ids separated by "||": amherst
# 75    Scanning center ids separated by "||": hangzhou
#
# [76 rows x 11 columns]

# %% [markdown]
# ## Measures
#
# adding measure info. Should be formatted as (measure_name,measure_value,measure_unit).

# %%
geocounts = pd.read_csv("https://raw.githubusercontent.com/ers6/ia_scanning_labor_data/refs/heads/main/metadata-analysis/metadata-records-analysis-csvs/geocounts.csv")[['name', 'total_scans']]

# %%
# total books scanned

geocounts

for i in range(len(manifest_df)): 
    for j in range(len(geocounts)): 
        if manifest_df.at[i, 'Name'] == geocounts.at[j,'name']: 
            measure_text = "(books_scanned,"+ str(geocounts.at[j,'total_scans'])+ ",books)"
            manifest_df.at[i, 'Measure'] += measure_text
        else:
            pass

# %%
# total pages scanned
# Out:
#     Index                                           Name Description  \
# 0       0                                  1 Dollar Scan
# 1       1  Allen County Public Library Geneaology Center
# 2       2             American Museum of Natural History
# 3       3             Washington University in St. Louis
# 4       4          American Printing House for the Blind
# ..    ...                                            ...         ...
# 71     71                          University of Toronto
# 72     72                         University of Victoria
# 73     73                          University of Warwick
# 74     74                            Yiddish Book Center
# 75     75                            Zhejiang University
#
#      Category Images Location                   Geocode DestinationIndex  \
# 0                              37.27838889,-121.9492601
# 1     #public                    41.0771285,-85.1432003
# 2     #museum                  40.78130431,-73.97404878
# 3   #academic                    38.649678,-90.32848246
# 4    #archive                  38.25759766,-85.71422071
# ..        ...    ...      ...                       ...              ...
# 71  #academic                  43.66441368,-79.39947221
# 72  #academic                   48.4633746,-123.3100252
# 73  #academic                  52.38161719,-1.561841996
# 74  #academic                  42.32188825,-72.52766762
# 75  #academic                    30.2628344,120.1190128
#
#                          Measure  \
# 0       (books_scanned,20,books)
# 1   (books_scanned,214706,books)
# 2       (books_scanned,29,books)
# 3    (books_scanned,18103,books)
# 4     (books_scanned,2326,books)
# ..                           ...
# 71  (books_scanned,465884,books)
# 72    (books_scanned,6843,books)
# 73     (books_scanned,715,books)
# 74    (books_scanned,1242,books)
# 75       (books_scanned,1,books)
#
#                                               Sources  \
# 0   (https://archive.org/search?query=scanningcent...
# 1   (https://archive.org/search?query=scanningcent...
# 2   (https://archive.org/search?query=scanningcent...
# 3   (https://archive.org/search?query=scanningcent...
# 4   (https://archive.org/search?query=scanningcent...
# ..                                                ...
# 71  (https://archive.org/search?query=scanningcent...
# 72  (https://archive.org/search?query=scanningcent...
# 73  (https://archive.org/search?query=scanningcent...
# 74  (https://archive.org/search?query=scanningcent...
# 75  (https://archive.org/search?query=scanningcent...
#
#                                       AdditionalNotes
# 0   Scanning center ids separated by "||": 1dollar...
# 1      Scanning center ids separated by "||": indiana
# 2      Scanning center ids separated by "||": tt_amnh
# 3   Scanning center ids separated by "||": tt_numi...
# 4   Scanning center ids separated by "||": tt_loui...
# ..                                                ...
# 71  Scanning center ids separated by "||": uoft||UofT
# 72  Scanning center ids separated by "||": tt_vict...
# 73  Scanning center ids separated by "||": tt_warwick
# 74     Scanning center ids separated by "||": amherst
# 75    Scanning center ids separated by "||": hangzhou
#
# [76 rows x 11 columns]

# %%
manifest_df.to_csv("/Users/elizabethschwartz/Documents/test_manifest.csv")

# %% [markdown]
# did add a chart view but no way to say 12 measures were connected in some way
# cumulative stat with a different node for each center
# we could add a measure that has gradiations in it
# map embed is coming
#
# IA supply chain 2010, IA supply chain 2011
#
# collections - lists a set of manifests
# load different data layers - any kind of geojson data, inbox data,
#
# lib/json/cases if you point manifest to #collective
